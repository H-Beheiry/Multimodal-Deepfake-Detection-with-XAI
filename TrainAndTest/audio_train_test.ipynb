# %%
from DatasetReaders.AudioDatset import AudioDatset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from DatasetReaders.AudioDatset import AudioDatset
#
# ModuleNotFoundError: No module named 'DatasetReaders'

# %%
import os
print(os.getcwd())
# Out:
# D:\f_uni\sophomore_Uni\semester_1\Profesinal_Project\multimodal_deepfake_detection\TrainAndTest
