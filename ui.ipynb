# %%
import gradio as gr
import os
import io
import torch
import librosa
import warnings
import torchaudio
from PIL import Image
import matplotlib.pyplot as plt
import torchvision.transforms as T



from Pipelines.AVPipeline import AVPipeline
from Pipelines.VideoPipeline import VideoPipeline
from Pipelines.AudioPipeline import AudioPipeline
from DetectionModels.AudioCNN import CNNnetwork
from DetectionModels.VideoResNet import VideoResNet
from DetectionModels.AVModel import AVModel


device= "cpu"

# %%
import torch.nn as nn

class DeviceSafeAudioTransform(nn.Module):
    def __init__(self, transform):
        super().__init__()
        self.transform = transform
    def forward(self, x):
        target_device = next(self.transform.buffers()).device
        return self.transform(x.to(target_device))

# %%
tau= 3.0
BATCH_SIZE= 4
SAMPLE_RATE= 16000
NUM_OF_MELS= 128
WIN_LENGTH= int(0.016 * SAMPLE_RATE)
HOP_LENGTH= int(0.004 * SAMPLE_RATE) 
FIXED_SPECTROGRAM_SIZE= (128, 750)

test_video_transform= T.Compose([
    T.Resize((224, 224)),
    T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
test_mel_spectrogram_transform= torch.nn.Sequential(
    torchaudio.transforms.MelSpectrogram(
        sample_rate=SAMPLE_RATE,
        n_fft=WIN_LENGTH*2,
        hop_length=HOP_LENGTH,
        n_mels=NUM_OF_MELS,
        window_fn=torch.hamming_window,
        win_length=WIN_LENGTH
    ),
    torchaudio.transforms.AmplitudeToDB(top_db=80),
    T.Resize(FIXED_SPECTROGRAM_SIZE)
)
test_mel_spectrogram_transform= DeviceSafeAudioTransform(test_mel_spectrogram_transform)
vid_params= {
    "tau": 3.0,
    "fps": 25
}
aud_params= {
    "sample_rate": 16000,
    "tau": 3.0
}


video_net= VideoResNet().to(device)
audio_net= CNNnetwork().to(device)
video_net.load_state_dict(torch.load("Video_model.pth",weights_only=True))
audio_net.load_state_dict(torch.load("Audio_CNN.pth",weights_only=True))
fusion_model= AVModel(video_net, audio_net).to(device)
fusion_model.load_state_dict(torch.load("AV_Fusion_Best.pth",weights_only=True))

av_pipeline= AVPipeline(fusion_model, test_video_transform, test_mel_spectrogram_transform, vid_params, aud_params)
video_pipeline= VideoPipeline(test_video_transform,3.0,25,device,video_net)
audio_pipeline= AudioPipeline(audio_net,test_mel_spectrogram_transform,SAMPLE_RATE,3.0,device)
# Out:
# D:\f_uni\sophomore_Uni\semester_1\Profesinal_Project\multimodal_deepfake_detection\dfd_env\lib\site-packages\torchaudio\functional\functional.py:584: UserWarning: At least one mel filterbank has all zero values. The value for `n_mels` (128) may be set too high. Or, the value for `n_freqs` (257) may be set too low.
#   warnings.warn(

# %%
def fig_to_img(fig):
    buf= io.BytesIO()
    fig.savefig(buf, format="png", bbox_inches='tight')
    buf.seek(0)
    img= Image.open(buf)
    return img

# %%
def create_dashboard(result, mode="audio"):
    fig = plt.figure(figsize=(16, 10))
    pred = result['prediction']
    color = "red" if pred == "FAKE" else "green"
    fig.suptitle(f"Model Prediction: {pred}", fontsize=20, fontweight='bold', color=color, y=0.95)
    ax_orig = plt.subplot2grid((2, 3), (0, 0), colspan=3)
    if mode == "audio":
        if result.get("signal"):
            ax_orig.imshow(result['signal'])
            ax_orig.set_title("Original Audio Signal", fontsize=14)
    elif mode == "video":
        if result.get("mid_frame"):
            ax_orig.imshow(result['mid_frame'])
            ax_orig.set_title("Original Video Frame", fontsize=14)
    ax_orig.axis('off')
    explanations = result.get("explination", [])
    titles = ["Saliency Map", "Integrated Gradients", "Layer GradCAM"]
    for i, img in enumerate(explanations):
        if i < 3:
            ax = plt.subplot2grid((2, 3), (1, i), colspan=1)
            ax.imshow(img)
            ax.set_title(f"{titles[i]}", fontsize=12)
            ax.axis('off')
    plt.tight_layout(rect=[0, 0, 1, 0.92])
    img = fig_to_img(fig)
    plt.close(fig)
    return img

# %%
def has_audio(file_path):
    try:
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            librosa.load(file_path, sr=None, duration=0.5)
        return True
    except Exception:
        return False

# %%
def predict_media(file):
    if file is None:
        return None, None
    file_path = file.name
    ext = os.path.splitext(file_path)[1].lower()
    if ext in [".wav", ".mp3", ".flac", ".aac"]:
        print("Running Audio Pipeline...")
        r = audio_pipeline.run(file_path)
        dashboard_img = create_dashboard(r, mode="audio")
        return r["prediction"], dashboard_img
    elif ext in [".mp4", ".avi", ".mov", ".mkv"]:
        audio_exists = has_audio(file_path)
        if audio_exists:
            print("Audio detected. Running AV Pipeline...")
            r = av_pipeline.run(file_path)
            dashboard_img = av_pipeline.visualize_result(r)
            return r["prediction"], dashboard_img
        else:
            print("No audio detected. Running Video Pipeline...")
            r = video_pipeline.run(file_path)
            dashboard_img = create_dashboard(r, mode="video")
            return r["prediction"], dashboard_img
    else:
        return "Error", None

# %%
with gr.Blocks(theme=gr.themes.Soft()) as demo:
    gr.Markdown("# Multimodal Deepfake Detection System")
    gr.Markdown("Upload an Audio or Video file and we will explain weather it is real or fake")

    with gr.Row():
        with gr.Column(scale=1):
            media_input = gr.File(
                label="Upload File",
                file_types=[".wav", ".mp3", ".flac", ".mp4", ".avi", ".mov"]
            )
            detect_btn = gr.Button("Analyze Media", variant="primary")
            pred_label = gr.Label(label="Prediction Result")
        with gr.Column(scale=2):
            result_dashboard = gr.Image(label="Analysis Dashboard", type="pil")
    detect_btn.click(
        fn=predict_media,
        inputs=media_input,
        outputs=[pred_label, result_dashboard]
    )

if __name__ == "__main__":
    demo.launch(debug=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "D:\f_uni\sophomore_Uni\semester_1\Profesinal_Project\multimodal_deepfake_detection\dfd_env\lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 403, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "D:\f_uni\sophomore_Uni\semester_1\Profesinal_Project\multimodal_deepfake_detection\dfd_env\lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
# ...
